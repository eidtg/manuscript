# %% [markdown]
# # Manuscript Title
#
# Manuscript Subtitle
#
# First Author [![](data:image/png;base64,...)](https://orcid.org/0000-0000-0000-0000) (Main Institution, Secondary Institution)
# Second Author [![](data:image/png;base64,...)](https://orcid.org/0000-0000-0000-0000) (Main Institution)
# Third Author [![](data:image/png;base64,...)](https://orcid.org/0000-0000-0000-0000) (Secondary Institution)
# 09 10 2025
#
# This is an abstract …

# %%
library(flextable)
library(glue)
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.2
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ purrr::compose() masks flextable::compose()
# ✖ dplyr::filter()  masks stats::filter()
# ✖ dplyr::lag()     masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# ## 1 Introduction
#
# The Codex Regius of the Poetic Edda is one of the most important medieval Icelandic manuscripts \[[1](#ref-colombo_2022)\].
#
# ## 2 Materials and Methods
#
# ## 3 Results
#
# ## 4 Discussion
#
# ## 5 Conclusions
#
# ## Authors contributions
#
# ## Fundind
#
# ## Competing interests

# %% [markdown]
# ## Figures
#
# [![Oluf Olufsen Bagge - Yggdrasil, The Mundane Tree 1847](attachment:images/yggdrasil.jpg)](https://the-public-domain-review.imgix.net/collections/yggdrasil-the-sacred-ash-tree-of-norse-mythology/oct_19_new_prints_00008.jpg?w=857)
#
# Figure 1: Oluf Olufsen Bagge - Yggdrasil, The Mundane Tree 1847

# %% [markdown]
# ## References
#
# <span class="csl-left-margin">\[1\] </span><span class="csl-right-inline">F. Colombo, “The young sigurðr section of the codex regius of the poetic edda (GKS 2365 4to): Compositional history and interpretative reading,” PhD thesis, Apollo - University of Cambridge Repository, 2022. doi: [10.17863/CAM.87662](https://doi.org/10.17863/CAM.87662).</span>
